# %%
"""import pandas as pd
df = pd.read_parquet('yellow_tripdata_2016-03.parquet')
df.head()
df.to_csv('data.csv')"""

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.shape
sample_df = df.sample(n=10000)

# %%
#sample_df.head()
sample_df.drop(['Unnamed: 0','congestion_surcharge', 'airport_fee'],axis =1, inplace = True)
sample_df.head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1735083         2  2016-03-05 08:41:38   2016-03-05 08:43:54                1
# 706648          1  2016-03-02 20:20:16   2016-03-02 20:34:19                2
# 9336722         2  2016-03-24 14:16:02   2016-03-24 14:31:11                5
# 7481101         1  2016-03-19 16:08:39   2016-03-19 16:40:01                1
# 20588           1  2016-03-01 05:00:44   2016-03-01 05:03:17                1
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 1735083           0.82           1                  N           142
# 706648            2.30           1                  N           186
# 9336722           4.16           1                  N            45
# 7481101           5.90           1                  N            43
# 20588             1.00           1                  N           263
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
sample_df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount'],
#       dtype='object')

# %%
sample_df.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
sample_df = sample_df.reset_index(drop=True)

# %%
sample_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-03-05 08:41:38   2016-03-05 08:43:54                1
# 1         1  2016-03-02 20:20:16   2016-03-02 20:34:19                2
# 2         2  2016-03-24 14:16:02   2016-03-24 14:31:11                5
# 3         1  2016-03-19 16:08:39   2016-03-19 16:40:01                1
# 4         1  2016-03-01 05:00:44   2016-03-01 05:03:17                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.82           1                  N           142           237
# 1           2.30           1                  N           186           237
# 2           4.16           1                  N            45           164
# 3           5.90           1                  N            43           249
# 4           1.00           1                  N           263           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
sample_df.to_csv('sample_data.csv')
